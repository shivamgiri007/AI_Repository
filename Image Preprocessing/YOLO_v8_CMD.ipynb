# %% [markdown]
# #Modes:
#
# train, val, predict
#
# #Tasks:
#
# detect, segment, classify
#
# #Data:
#
# Format can be differ for task type, Supports data.yaml, data_folder, data_name

# %% [markdown]
# # Installation

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 25.1 MB/s eta 0:00:00

# %% [markdown]
# ## CMD

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 1. Detection:

# %%
# !yolo task=detect mode=predict model=yolo11n.pt source="/content/people-1979261_1280.jpg"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 5.35M/5.35M [00:00<00:00, 128MB/s]
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# image 1/1 /content/people-1979261_1280.jpg: 448x640 7 persons, 3 ties, 1 dining table, 1 laptop, 2 cell phones, 43.8ms
# Speed: 13.1ms preprocess, 43.8ms inference, 776.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Segmentation:

# %%
# !yolo task=segment mode=predict model=yolo11n-seg.pt source="/content/people-1979261_1280.jpg"
# Out:
# ...
# 100% 5.90M/5.90M [00:00<00:00, 111MB/s]
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n-seg summary (fused): 265 layers, 2,868,664 parameters, 0 gradients, 10.4 GFLOPs
#
# image 1/1 /content/people-1979261_1280.jpg: 448x640 6 persons, 1 tie, 1 dining table, 1 laptop, 55.8ms
# Speed: 4.0ms preprocess, 55.8ms inference, 523.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !rm -rf /content/runs

# %% [markdown]
# ## Python Script

# %%
from ultralytics import YOLO

# Load a segmentation model
model = YOLO("yolov8n-seg.pt")
model.predict(source="/content/entrepreneur-593358_640.jpg")
# Out:
# image 1/1 /content/entrepreneur-593358_640.jpg: 448x640 1 person, 129.6ms
# Speed: 3.0ms preprocess, 129.6ms inference, 692.4ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %% [markdown]
# # 3. Classification:

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="/content/people-1979261_1280.jpg"
# Out:
# ...
# 100% 5.31M/5.31M [00:00<00:00, 94.1MB/s]
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 19.5MB/s]
# image 1/1 /content/people-1979261_1280.jpg: 224x224 notebook 0.43, bow_tie 0.35, groom 0.07, mouse 0.04, suit 0.03, 2.7ms
# Speed: 45.3ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
